# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
 #from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse'],
 'max_features': ['sqrt','log2'],
 'n_estimators':[10,50,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
 # fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
 # print best parameter after tuning
 #print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.131648      0.005076         0.017208        0.003541
# 1        0.434561      0.016915         0.031295        0.003964
# 2        0.862213      0.022384         0.046324        0.004333
# 3        0.092661      0.005198         0.012656        0.000773
# 4        0.412913      0.032547         0.027271        0.003561
# 5        0.856101      0.026225         0.061556        0.005030
# 6        0.336268      0.030703         0.015489        0.004911
# 7        1.406306      0.021682         0.027804        0.003544
# 8        2.682934      0.051652         0.042828        0.005346
# 9        0.281393      0.007519         0.012034        0.004568
# 10       1.337156      0.017888         0.025788        0.002498
# 11       2.779025      0.113076         0.062673        0.010397
# 12       0.078670      0.003267         0.010992        0.001377
# 13       0.358475      0.005649         0.026487        0.003958
# 14       0.805256      0.094089         0.061890        0.010516
# 15       0.098660      0.007870         0.013120        0.001661
# 16       0.519214      0.023654         0.039366        0.008033
# 17       0.871127      0.037268         0.046403        0.009558
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                  50
# 2    squared_error               sqrt                 100
# 3    squared_error               log2                  10
# 4    squared_error               log2                  50
# 5    squared_error               log2                 100
# 6   absolute_error               sqrt                  10
# 7   absolute_error               sqrt                  50
# 8   absolute_error               sqrt                 100
# 9   absolute_error               log2                  10
# 10  absolute_error               log2                  50
# 11  absolute_error               log2                 100
# 12    friedman_mse               sqrt                  10
# 13    friedman_mse               sqrt                  50
# 14    friedman_mse               sqrt                 100
# 15    friedman_mse               log2                  10
# 16    friedman_mse               log2                  50
# 17    friedman_mse               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.829850
# 1   {'criterion': 'squared_error', 'max_features':...           0.857695
# 2   {'criterion': 'squared_error', 'max_features':...           0.855693
# 3   {'criterion': 'squared_error', 'max_features':...           0.849214
# 4   {'criterion': 'squared_error', 'max_features':...           0.857940
# 5   {'criterion': 'squared_error', 'max_features':...           0.853250
# 6   {'criterion': 'absolute_error', 'max_features'...           0.842569
# 7   {'criterion': 'absolute_error', 'max_features'...           0.851136
# 8   {'criterion': 'absolute_error', 'max_features'...           0.857679
# 9   {'criterion': 'absolute_error', 'max_features'...           0.838194
# 10  {'criterion': 'absolute_error', 'max_features'...           0.852993
# 11  {'criterion': 'absolute_error', 'max_features'...           0.859616
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.844204
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.852504
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.852194
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.841377
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.860448
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.855487
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.757883           0.837374           0.813079
# 1            0.775408           0.861770           0.828300
# 2            0.786009           0.859563           0.832220
# 3            0.765426           0.844078           0.803926
# 4            0.778235           0.857111           0.826391
# 5            0.778035           0.860589           0.828815
# 6            0.754096           0.833651           0.808675
# 7            0.783321           0.851311           0.821783
# 8            0.776310           0.859195           0.828212
# 9            0.760219           0.834708           0.818144
# 10           0.779525           0.852834           0.826641
# 11           0.779019           0.855069           0.826512
# 12           0.753696           0.839297           0.797911
# 13           0.780625           0.853842           0.827860
# 14           0.778434           0.860919           0.831521
# 15           0.749185           0.838560           0.809457
# 16           0.780482           0.858607           0.826261
# 17           0.776715           0.855063           0.830335
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.821343         0.811906        0.028212               17
# 1            0.835588         0.831752        0.030905                7
# 2            0.842723         0.835242        0.026453                1
# 3            0.831243         0.818777        0.030948               13
# 4            0.832189         0.830373        0.029025               11
# 5            0.842957         0.832729        0.029355                3
# 6            0.810991         0.809996        0.030816               18
# 7            0.831948         0.827900        0.025016               12
# 8            0.839667         0.832213        0.030243                5
# 9            0.828855         0.816024        0.028719               14
# 10           0.843847         0.831168        0.027546               10
# 11           0.840518         0.832147        0.028998                6
# 12           0.843361         0.815694        0.035484               15
# 13           0.841873         0.831341        0.027016                9
# 14           0.838165         0.832247        0.028815                4
# 15           0.827024         0.813121        0.033882               16
# 16           0.838592         0.832878        0.029134                2
# 17           0.839434         0.831407        0.028970                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 31
# BMI: 30
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[24489.8512282]
# C:\Users\Priyan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
