# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV
# Define parameter grid for SVR
param_grid = {
    'kernel': ['poly', 'rbf', 'sigmoid'],
    'C': [0.1, 1, 10],
}

# Create GridSearchCV object
grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)

# Fit the model
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10],
#                          'kernel': ['poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
# print best parameter after tuning
 #print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 1, 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.064743      0.003348         0.013409        0.001291      0.1
# 1       0.079895      0.004701         0.039657        0.002061      0.1
# 2       0.092582      0.003295         0.021674        0.001466      0.1
# 3       0.068399      0.002430         0.012678        0.001658      1.0
# 4       0.083008      0.002060         0.037191        0.001435      1.0
# 5       0.098027      0.005151         0.020184        0.000861      1.0
# 6       0.072192      0.004125         0.012450        0.000639     10.0
# 7       0.083446      0.005065         0.036115        0.003712     10.0
# 8       0.094508      0.002172         0.019391        0.002594     10.0
#
#   param_kernel                           params  split0_test_score  \
# 0         poly     {'C': 0.1, 'kernel': 'poly'}          -0.112857
# 1          rbf      {'C': 0.1, 'kernel': 'rbf'}          -0.115326
# 2      sigmoid  {'C': 0.1, 'kernel': 'sigmoid'}          -0.115314
# 3         poly       {'C': 1, 'kernel': 'poly'}          -0.093867
# 4          rbf        {'C': 1, 'kernel': 'rbf'}          -0.115390
# 5      sigmoid    {'C': 1, 'kernel': 'sigmoid'}          -0.115186
# 6         poly      {'C': 10, 'kernel': 'poly'}          -0.125153
# 7          rbf       {'C': 10, 'kernel': 'rbf'}          -0.110409
# 8      sigmoid   {'C': 10, 'kernel': 'sigmoid'}          -0.116743
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.105099          -0.077609          -0.104969          -0.108333
# 1          -0.113152          -0.081428          -0.105862          -0.107303
# 2          -0.113654          -0.081616          -0.106034          -0.107251
# 3          -0.073490          -0.065017          -0.092734          -0.112204
# 4          -0.110235          -0.079858          -0.104068          -0.108358
# 5          -0.114434          -0.081691          -0.105744          -0.107748
# 6          -0.081505          -0.111907          -0.131602          -0.179328
# 7          -0.097459          -0.074488          -0.099597          -0.124428
# 8          -0.119312          -0.085214          -0.108210          -0.108716
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.101773        0.012418                3
# 1        -0.104614        0.012116                5
# 2        -0.104774        0.012116                6
# 3        -0.087462        0.016613                1
# 4        -0.103582        0.012406                4
# 5        -0.104961        0.012200                7
# 6        -0.125899        0.031794                9
# 7        -0.101276        0.016459                2
# 8        -0.107639        0.012029                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 31
# BMI: 30
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[7616.65998693]
# C:\Users\Priyan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
