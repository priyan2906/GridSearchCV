# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Decision Tree
param_grid = {
    'criterion': ['squared_error', 'absolute_error'],
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10]
}

# Create GridSearchCV object
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

# Fit the model
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [None, 5, 10, 20],
#                          'min_samples_split': [2, 5, 10]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_depth': 5, 'min_samples_split': 2}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.019650      0.002413         0.006001        0.001448
# 1        0.015684      0.003389         0.007341        0.001219
# 2        0.012676      0.002503         0.006608        0.002082
# 3        0.011620      0.001193         0.004871        0.001318
# 4        0.010232      0.001055         0.007457        0.000710
# 5        0.007933      0.001491         0.005558        0.001034
# 6        0.010012      0.001078         0.004712        0.001132
# 7        0.009550      0.000934         0.005182        0.000951
# 8        0.007626      0.000617         0.004119        0.001284
# 9        0.011394      0.001090         0.004613        0.000416
# 10       0.009355      0.001865         0.004294        0.000821
# 11       0.009556      0.001558         0.004667        0.001482
# 12       0.076957      0.003219         0.005029        0.000751
# 13       0.071743      0.003758         0.005430        0.001270
# 14       0.070513      0.003377         0.005679        0.001394
# 15       0.059574      0.003159         0.004974        0.001695
# 16       0.057305      0.002143         0.005193        0.000897
# 17       0.058614      0.003194         0.006556        0.001717
# 18       0.074078      0.003467         0.004824        0.000799
# 19       0.068027      0.002459         0.005133        0.001025
# 20       0.067716      0.004633         0.005454        0.001019
# 21       0.071906      0.006432         0.005223        0.000644
# 22       0.069054      0.005955         0.006998        0.002521
# 23       0.064199      0.009752         0.005007        0.001207
#
#    param_criterion param_max_depth  param_min_samples_split  \
# 0    squared_error            None                        2
# 1    squared_error            None                        5
# 2    squared_error            None                       10
# 3    squared_error               5                        2
# 4    squared_error               5                        5
# 5    squared_error               5                       10
# 6    squared_error              10                        2
# 7    squared_error              10                        5
# 8    squared_error              10                       10
# 9    squared_error              20                        2
# 10   squared_error              20                        5
# 11   squared_error              20                       10
# 12  absolute_error            None                        2
# 13  absolute_error            None                        5
# 14  absolute_error            None                       10
# 15  absolute_error               5                        2
# 16  absolute_error               5                        5
# 17  absolute_error               5                       10
# 18  absolute_error              10                        2
# 19  absolute_error              10                        5
# 20  absolute_error              10                       10
# 21  absolute_error              20                        2
# 22  absolute_error              20                        5
# 23  absolute_error              20                       10
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_depth': No...           0.712895
# 1   {'criterion': 'squared_error', 'max_depth': No...           0.745176
# 2   {'criterion': 'squared_error', 'max_depth': No...           0.831445
# 3   {'criterion': 'squared_error', 'max_depth': 5,...           0.870997
# 4   {'criterion': 'squared_error', 'max_depth': 5,...           0.871005
# 5   {'criterion': 'squared_error', 'max_depth': 5,...           0.871005
# 6   {'criterion': 'squared_error', 'max_depth': 10...           0.769260
# 7   {'criterion': 'squared_error', 'max_depth': 10...           0.778321
# 8   {'criterion': 'squared_error', 'max_depth': 10...           0.834786
# 9   {'criterion': 'squared_error', 'max_depth': 20...           0.716167
# 10  {'criterion': 'squared_error', 'max_depth': 20...           0.745231
# 11  {'criterion': 'squared_error', 'max_depth': 20...           0.831445
# 12  {'criterion': 'absolute_error', 'max_depth': N...           0.745643
# 13  {'criterion': 'absolute_error', 'max_depth': N...           0.759217
# 14  {'criterion': 'absolute_error', 'max_depth': N...           0.821716
# 15  {'criterion': 'absolute_error', 'max_depth': 5...           0.885227
# 16  {'criterion': 'absolute_error', 'max_depth': 5...           0.885227
# 17  {'criterion': 'absolute_error', 'max_depth': 5...           0.885227
# 18  {'criterion': 'absolute_error', 'max_depth': 1...           0.755877
# 19  {'criterion': 'absolute_error', 'max_depth': 1...           0.777888
# 20  {'criterion': 'absolute_error', 'max_depth': 1...           0.827804
# 21  {'criterion': 'absolute_error', 'max_depth': 2...           0.742598
# 22  {'criterion': 'absolute_error', 'max_depth': 2...           0.752727
# 23  {'criterion': 'absolute_error', 'max_depth': 2...           0.821852
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.649672           0.726261           0.740409
# 1            0.699108           0.766834           0.745414
# 2            0.728182           0.798664           0.779250
# 3            0.780551           0.874556           0.822363
# 4            0.780551           0.874556           0.822363
# 5            0.780572           0.874556           0.822363
# 6            0.666320           0.763054           0.754293
# 7            0.704529           0.789673           0.753241
# 8            0.730991           0.802846           0.779657
# 9            0.658154           0.736466           0.734314
# 10           0.698460           0.764648           0.745539
# 11           0.728527           0.798664           0.779250
# 12           0.591509           0.723903           0.708553
# 13           0.660347           0.784153           0.764142
# 14           0.749595           0.825822           0.793156
# 15           0.781353           0.881422           0.820862
# 16           0.781353           0.881422           0.820862
# 17           0.781353           0.881422           0.820862
# 18           0.716821           0.747180           0.775097
# 19           0.733095           0.794869           0.777229
# 20           0.749412           0.832392           0.793209
# 21           0.633781           0.729093           0.720379
# 22           0.674002           0.784700           0.774946
# 23           0.749593           0.825741           0.793202
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.661897         0.698227        0.035938               24
# 1            0.756379         0.742582        0.023166               19
# 2            0.784032         0.784315        0.033477               12
# 3            0.861057         0.841905        0.035848                6
# 4            0.861384         0.841972        0.035885                5
# 5            0.861384         0.841976        0.035877                4
# 6            0.762592         0.743104        0.038686               18
# 7            0.789796         0.763112        0.032182               14
# 8            0.803927         0.790441        0.034505               10
# 9            0.685975         0.706215        0.030077               23
# 10           0.758231         0.742422        0.023213               20
# 11           0.784077         0.784392        0.033362               11
# 12           0.762087         0.706339        0.060253               22
# 13           0.786257         0.750823        0.046476               17
# 14           0.806917         0.799441        0.027467                9
# 15           0.849352         0.843643        0.038957                1
# 16           0.849352         0.843643        0.038957                1
# 17           0.849352         0.843643        0.038957                1
# 18           0.779141         0.754823        0.022388               15
# 19           0.789177         0.774452        0.021742               13
# 20           0.807127         0.801989        0.029862                7
# 21           0.743501         0.713870        0.040967               21
# 22           0.785477         0.754370        0.041887               16
# 23           0.806917         0.799461        0.027472                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 30
# BMI: 30
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19444.2658]
# C:\Users\Priyan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
